# %% [markdown]
# <a href="https://colab.research.google.com/github/Bongbong12/CitraDigital/blob/main/Remedial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar
image_path = "view.jpg"
image = cv2.imread(image_path)

# Konversi gambar dari BGR ke RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Memisahkan channel R, G, B
channels = cv2.split(image_rgb)
colors = ('red', 'green', 'blue')

# Membuat histogram gabungan
plt.figure(figsize=(10, 6))
plt.title("Combined Histogram of RGB Channels")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")

for channel, color in zip(channels, colors):
    hist = cv2.calcHist([channel], [0], None, [256], [0, 256])
    plt.plot(hist, color=color)

plt.legend(colors)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Menampilkan gambar asli
plt.figure(figsize=(6, 6))
plt.title("Original Image")
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar
image_path = "wajah.jpg"
image = cv2.imread(image_path)

# Konversi gambar dari BGR ke RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Memisahkan channel R, G, B
channels = cv2.split(image_rgb)
colors = ('red', 'green', 'blue')

# Membuat histogram gabungan
plt.figure(figsize=(10, 6))
plt.title("Combined Histogram of RGB Channels")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")

for channel, color in zip(channels, colors):
    hist = cv2.calcHist([channel], [0], None, [256], [0, 256])
    plt.plot(hist, color=color)

plt.legend(colors)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Menampilkan gambar asli
plt.figure(figsize=(6, 6))
plt.title("Original Image")
plt.imshow(image_rgb)
plt.axis('off')
plt.show()
